# %%
import os
import json

kaggle_key_path = '../keys/kaggle.json'

with open(kaggle_key_path, 'r') as file:
    kaggle_creds = json.load(file)

os.environ['KAGGLE_USERNAME'] = kaggle_creds['username'] # username from the json file
os.environ['KAGGLE_KEY'] = kaggle_creds['key'] # key from the json file
import kaggle
import pandas as pd

# %%
print(kaggle)
# Out:
# <module 'kaggle' from '/Users/lucasderr/opt/anaconda3/lib/python3.9/site-packages/kaggle/__init__.py'>

# %%
name = "sobhanmoosavi/us-weather-events"


kaggle.api.authenticate()

kaggle.api.dataset_download_files(name, path='dataset', unzip=True)
# Out:
# Dataset URL: https://www.kaggle.com/datasets/sobhanmoosavi/us-weather-events

# %%
directory = "dataset"
old_file_path = os.path.join(directory, "WeatherEvents_Jan2016-Dec2022.csv")
new_file_path = os.path.join(directory, "airport_weather_bulk.csv")

os.rename(old_file_path, new_file_path)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /var/folders/bh/bkzmld751m5fdgn8m3_kzfmc0000gn/T/ipykernel_31048/1641989137.py in <module>
#       3 new_file_path = os.path.join(directory, "airport_weather_bulk.csv")
#       4
# ----> 5 os.rename(old_file_path, new_file_path)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'dataset/WeatherEvents_Jan2016-Dec2022.csv' -> 'dataset/airport_weather_bulk.csv'

# %%
path = "/Users/lucasderr/Desktop/Ski-Resort-Weather-Dashboard/bulk_weather_data/airport_weather_bulk.csv"
reader = pd.read_csv(path, iterator=True)

# %%
chunk_size = 100000 
chunk = reader.get_chunk(chunk_size)

# %%
chunk
# Out:
#         EventId  Type Severity       StartTime(UTC)         EndTime(UTC)  \
# 0           W-1  Snow    Light  2016-01-06 23:14:00  2016-01-07 00:34:00
# 1           W-2  Snow    Light  2016-01-07 04:14:00  2016-01-07 04:54:00
# 2           W-3  Snow    Light  2016-01-07 05:54:00  2016-01-07 15:34:00
# 3           W-4  Snow    Light  2016-01-08 05:34:00  2016-01-08 05:54:00
# 4           W-5  Snow    Light  2016-01-08 13:54:00  2016-01-08 15:54:00
# ...         ...   ...      ...                  ...                  ...
# 99995  W-105011  Rain    Light  2021-12-09 20:53:00  2021-12-09 21:53:00
# 99996  W-105012  Rain    Light  2021-12-09 22:39:00  2021-12-09 22:53:00
# 99997  W-105013  Rain    Light  2021-12-10 09:53:00  2021-12-10 11:53:00
# 99998  W-105014  Rain    Light  2021-12-10 12:42:00  2021-12-10 12:53:00
# 99999  W-105015  Rain    Light  2021-12-10 22:53:00  2021-12-11 02:53:00
#
#        Precipitation(in)     TimeZone AirportCode  LocationLat  LocationLng  \
# ...

# %%
# !pip install opendatasets
import opendatasets

# %%
url = "https://www.kaggle.com/datasets/sobhanmoosavi/us-weather-events"
opendatasets.download('https://www.kaggle.com/tunguz/us-elections-dataset')
# Out:
# Please provide your Kaggle credentials to download this dataset. Learn more: http://bit.ly/kaggle-creds
# Your Kaggle username:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.9/site-packages/click/termui.py in prompt_func(text)
#     128             echo(text, nl=False, err=err)
# --> 129             return f("")
#     130         except (KeyboardInterrupt, EOFError):
#
# ~/opt/anaconda3/lib/python3.9/site-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#    1176             )
# -> 1177         return self._input_request(
#    1178             str(prompt),
#
# ~/opt/anaconda3/lib/python3.9/site-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#    1218                 # re-raise KeyboardInterrupt, to truncate traceback
# ...
